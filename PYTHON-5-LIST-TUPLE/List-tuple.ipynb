# %% [markdown]
# # List

# %% [markdown]
# # creating the list

# %%
# ZOMATO ORDER - CREATING LIST

food_order = []

# %%
name = "Manoj"

# %%
type(name)
# Out:
# str

# %%
type(food_order)
# Out:
# list

# %%
food_order = ["buttter chicken", "paneer tikka","chicken biryani", "mutton curry"]

# %%
type(food_order)
# Out:
# list

# %%
cart = []
history = list()

# %%
type(history)
# Out:
# list

# %%
prices = [250, 200, 300, 350]
ipa_score = [165, 170, 160, 175]

# %%
print(f"Food order: {food_order}")
print(f"Cart: {cart}")
print(f"History: {history}")
print(f"Prices: {prices}")
print(f"IPA Score: {ipa_score}")
# Out:
# Food order: ['buttter chicken', 'paneer tikka', 'chicken biryani', 'mutton curry']
# Cart: []
# History: []
# Prices: [250, 200, 300, 350]
# IPA Score: [165, 170, 160, 175]

# %%
restarunt_info = ["pizza hut", 4.1, "True", 45, None]

# %%
print(f"Restaurant Info: {restarunt_info}")
# Out:
# Restaurant Info: ['pizza hut', 4.1, 'True', 45, None]

# %%
# accessing the elemets in the list

order_items = ["Chicken","Biriyani","veg Briyani","Panner"]

# %%
print(f"am extracting biriyani: {order_items[1]}")
# Out:
# am extracting biriyani: Biriyani

# %%
len(order_items)
# Out:
# 4

# %%
order_items[2]
# Out:
# 'veg Briyani'

# %%
order_items[3]
# Out:
# 'Panner'

# %%
order_items[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 order_items[100]
#
# IndexError: list index out of range

# %%
# slicing 

order_items[1:3]
# Out:
# ['Biriyani', 'veg Briyani']

# %%
order_items[-2]
# Out:
# 'veg Briyani'

# %%
order_items[-1:-2]
# Out:
# []

# %%
order_items[::-1]
# Out:
# ['Panner', 'veg Briyani', 'Biriyani', 'Chicken']

# %%
order_items[-4:-1]
# Out:
# ['Chicken', 'Biriyani', 'veg Briyani']

# %%
cart = ["Paneer Maxxx Makhani","Paneer Maxxx Tandoori","Chicken Maxxx - BBQ"]

print(f"Initial cart items: {cart}")
# Out:
# Initial cart items: ['Paneer Maxxx Makhani', 'Paneer Maxxx Tandoori', 'Chicken Maxxx - BBQ']

# %%
cart.append("Garlic Breadsticks + Beverage")

# %%
print(f"Updated cart items: {cart}")
# Out:
# Updated cart items: ['Paneer Maxxx Makhani', 'Paneer Maxxx Tandoori', 'Chicken Maxxx - BBQ', 'Garlic Breadsticks + Beverage']

# %%
print(cart)
# Out:
# ['Paneer Maxxx Makhani', 'ice creame', 'ice creame', 'ice creame', 'Paneer Maxxx Tandoori', 'Chicken Maxxx - BBQ', 'Garlic Breadsticks + Beverage']

# %%
cart
# Out:
# ['Paneer Maxxx Makhani',
#  'ice creame',
#  'ice creame',
#  'ice creame',
#  'Paneer Maxxx Tandoori',
#  'Chicken Maxxx - BBQ',
#  'Garlic Breadsticks + Beverage']

# %%
cart.remove("ice creame")

# %%
print(cart)
# Out:
# ['Paneer Maxxx Makhani', 'ice creame', 'ice creame', 'Paneer Maxxx Tandoori', 'Chicken Maxxx - BBQ', 'Garlic Breadsticks + Beverage']

# %%
cart.remove("ice creame")

# %%
cart.remove("ice creame")

# %%
cart
# Out:
# ['Paneer Maxxx Makhani',
#  'Paneer Maxxx Tandoori',
#  'Chicken Maxxx - BBQ',
#  'Garlic Breadsticks + Beverage']

# %%
cart.insert(1, "ice creame")

# %%
print(f"Cart items after re-inserting ice creame: {cart}")
# Out:
# Cart items after re-inserting ice creame: ['Paneer Maxxx Makhani', 'ice creame', 'Paneer Maxxx Tandoori', 'Chicken Maxxx - BBQ', 'Garlic Breadsticks + Beverage']

# %%
another_order = ["Chocolate Cake", "Vanilla Ice Cream"]

# %%
cart.extend(another_order)
cart
# Out:
# ['Paneer Maxxx Makhani',
#  'ice creame',
#  'Paneer Maxxx Tandoori',
#  'Chicken Maxxx - BBQ',
#  'Garlic Breadsticks + Beverage',
#  'Chocolate Cake',
#  'Vanilla Ice Cream']

# %%
cart
# Out:
# ['Paneer Maxxx Makhani',
#  'ice creame',
#  'Paneer Maxxx Tandoori',
#  'Chicken Maxxx - BBQ',
#  'Garlic Breadsticks + Beverage',
#  'Chocolate Cake',
#  'Vanilla Ice Cream']

# %%
removed_item = cart.pop()

# %%
removed_item
# Out:
# 'Vanilla Ice Cream'

# %%
cart
# Out:
# ['Paneer Maxxx Makhani',
#  'ice creame',
#  'Paneer Maxxx Tandoori',
#  'Chicken Maxxx - BBQ',
#  'Garlic Breadsticks + Beverage',
#  'Chocolate Cake']

# %%
removed_item = cart.pop(1)

# %%
removed_item
# Out:
# 'ice creame'

# %%
cart
# Out:
# ['Paneer Maxxx Makhani',
#  'Paneer Maxxx Tandoori',
#  'Chicken Maxxx - BBQ',
#  'Garlic Breadsticks + Beverage',
#  'Chocolate Cake']

# %%
numb = [3,5,6,3,9,4,7,1]

# %%
numb.sort()

# %%
numb
# Out:
# [1, 3, 3, 4, 5, 6, 7, 9]

# %%
numb.reverse()

# %%
numb
# Out:
# [9, 7, 6, 5, 4, 3, 3, 1]

# %%
count = numb.count(3)
count
# Out:
# 2

# %%
max(numb)
# Out:
# 9

# %%
min(numb)
# Out:
# 1

# %%
sum(numb)
# Out:
# 38

# %%
test = "Hello, World!"

# %%
ls = test.split()

# %%
ls
# Out:
# ['Hello,', 'World!']

# %%
ls[0].upper()
# Out:
# 'HELLO,'

# %%
team_string = ",".join(ls)

# %%
team_string
# Out:
# 'Hello,,World!'

# %%
test_words = ["Manoj","ankit","Ganesh","Ravi"]

test_words[0] = "Tejas"

# %%
test_words
# Out:
# ['Tejas', 'ankit', 'Ganesh', 'Ravi']

# %% [markdown]
# # TUPLES

# %%
days_of_week = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday")
days_of_week
# Out:
# ('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday')

# %%
type(days_of_week)
# Out:
# tuple

# %%
months = ("January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December")

# %%
type(months)
# Out:
# tuple

# %%
months
# Out:
# ('January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December')

# %%
print(f"First Day of the Week: {days_of_week[0]}")
print(f"First Month of the Year: {months[0]}")
# Out:
# First Day of the Week: Monday
# First Month of the Year: January

# %%
days_of_week[0] = "Boring day"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 days_of_week[0] = "Boring day"
#
# TypeError: 'tuple' object does not support item assignment

# %%
print("Days of count: ", len(days_of_week))
print("Months of count: ", len(months))
# Out:
# Days of count:  7
# Months of count:  12

# %%
a = 10
b = 20

a, b = b,a
print(f"a: {a}, b: {b}")
# Out:
# a: 20, b: 10

# %%
students = ("Alice", "Bob", "Charlie", "David")
students
# Out:
# ('Alice', 'Bob', 'Charlie', 'David')

# %%
name1 , name2 , name3 , name4 = students
print(f"name1: {name1}, name2: {name2}, name3: {name3}, name4: {name4}")
# Out:
# name1: Alice, name2: Bob, name3: Charlie, name4: David

# %%
name1 , name2 , name3  = students
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 name1 , name2 , name3  = students
#
# ValueError: too many values to unpack (expected 3, got 4)

# %%
bio_data = ("Alice", 25, "Engineer")

# %%
name, age, profession = bio_data

# %%
print(f"name: {name}, age: {age}, profession: {profession}")
# Out:
# name: Alice, age: 25, profession: Engineer

# %%
name, age = bio_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 name, age = bio_data
#
# ValueError: too many values to unpack (expected 2, got 3)

# %% [markdown]
# ```

# %%
pods = ["nginx","busybox","redis"]

pods.append("httpd")
print(pods)
# Out:
# ['nginx', 'busybox', 'redis', 'httpd']

# %%
pod_config = ("nginx",80)

name, port = pod_config

# %%
print(name)
# Out:
# nginx

# %% [markdown]
# ### Build: **Movie Watchlist Manager**
#
# ```
# Features:
# 1. Start with an empty watchlist = []
# 2. Show a menu:
#    a) Add movie
#    b) Remove movie
#    c) Mark as watched (move from watchlist to watched_list)
#    d) Show all (watchlist + watched count)
#    e) Show stats (total, watched, remaining)
#    f) Sort watchlist alphabetically
#    g) Exit
#
# 3. Use separate lists: watchlist = [] and watched = []
# 4. When user types a movie name to remove, handle if it's not found
# 5. Show a recommendation: "You've watched X movies! Great job!"
#
# Sample output:
#   🎬 WATCHLIST MANAGER
#   ─────────────────────
#   Pending  (3): Inception, Interstellar, The Dark Knight
#   Watched  (2): Parasite, 3 Idiots
#
#   Stats: 5 total | 2 watched | 3 remaining
